# %% [markdown]
# ## Practical 2 : Multiple Linear Regression

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn import metrics
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_csv("D:\Krinal-sem6\Machine learning\Practical-2\concrete_data.csv")
df
# Out:
#       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       Coarse Aggregate  Fine Aggregate  Age  Strength
# 0               1040.0           676.0   28     79.99
# ...

# %% [markdown]
# # Data Visualization

# %%
sns.jointplot(x=df['Cement'], y=df['Strength'], data=df, kind='reg')

# %%
sns.jointplot(x=df['Blast Furnace Slag'], y=df['Strength'], data=df, kind='reg')

# %%
X= df[['Cement']]

Y=df[['Strength']]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
x_train=x_train['Cement'].to_numpy()
x_test=x_test['Cement'].to_numpy()
y_train=y_train['Strength'].to_numpy()
y_test=y_test['Strength'].to_numpy()


print('Train - Predictors shape', x_train.shape)
x_train = np.reshape(x_train, (-1,1))
x_test = np.reshape(x_test, (-1,1))
y_train = np.reshape(y_train, (-1,1))
y_test = np.reshape(y_test, (-1,1))

#
print('Train - Predictors shape', x_train.shape)
print('Test - Predictors shape', x_test.shape)
print('Train - Target shape', y_train.shape)
print('Test - Target shape', y_test.shape)
# Out:
# Train - Predictors shape (824,)
# Train - Predictors shape (824, 1)
# Test - Predictors shape (206, 1)
# Train - Target shape (824, 1)
# Test - Target shape (206, 1)

# %%
cls = linear_model.LinearRegression()
#Fit method is used for fitting your training data into the model
cls.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction = cls.predict(x_test)

# %% [markdown]
# ## Fitting Linear Regression

# %%
cls.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': False}

# %%
print('Co-efficient of linear regression',cls.coef_)
# Out:
# Co-efficient of linear regression [[0.07789607]]

# %%
print('Intercept of linear regression model',cls.intercept_)
# Out:
# Intercept of linear regression model [13.78517188]

# %%
print('Mean Square Error', metrics.mean_squared_error(y_test, prediction))
# Out:
# Mean Square Error 192.78479855432548

# %%
print('Model R^2 Square value', metrics.r2_score(y_test, prediction))
# Out:
# Model R^2 Square value 0.25183513628298093

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test, prediction, color='red', linewidth=3)
plt.xlabel('Cement')
plt.ylabel('Strength')
plt.title('Linear Regression')
# Out:
# Text(0.5, 1.0, 'Linear Regression')

# %%
X= df[['Blast Furnace Slag']]

Y=df[['Strength']]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
x_train=x_train['Blast Furnace Slag'].to_numpy()
x_test=x_test['Blast Furnace Slag'].to_numpy()
y_train=y_train['Strength'].to_numpy()
y_test=y_test['Strength'].to_numpy()


print('Train - Predictors shape', x_train.shape)
x_train = np.reshape(x_train, (-1,1))
x_test = np.reshape(x_test, (-1,1))
y_train = np.reshape(y_train, (-1,1))
y_test = np.reshape(y_test, (-1,1))

#
print('Train - Predictors shape', x_train.shape)
print('Test - Predictors shape', x_test.shape)
print('Train - Target shape', y_train.shape)
print('Test - Target shape', y_test.shape)
# Out:
# Train - Predictors shape (824,)
# Train - Predictors shape (824, 1)
# Test - Predictors shape (206, 1)
# Train - Target shape (824, 1)
# Test - Target shape (206, 1)

# %%
cls = linear_model.LinearRegression()
#Fit method is used for fitting your training data into the model
cls.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction = cls.predict(x_test)

# %%
print('Co-efficient of linear regression',cls.coef_)
# Out:
# Co-efficient of linear regression [[0.03008557]]

# %%
print('Intercept of linear regression model',cls.intercept_)
# Out:
# Intercept of linear regression model [33.62035217]

# %%
print('Mean Square Error', metrics.mean_squared_error(y_test, prediction))
# Out:
# Mean Square Error 260.3152656753102

# %%
print('Model R^2 Square value', metrics.r2_score(y_test, prediction))
# Out:
# Model R^2 Square value -0.010239068266299611

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test, prediction, color='red', linewidth=3)
plt.xlabel('Blast Furnace Slag')
plt.ylabel('Strength')
plt.title('Linear Regression')
# Out:
# Text(0.5, 1.0, 'Linear Regression')

# %%
plt.scatter(cls.predict(x_test), cls.predict(x_test) - y_test, c='g', s = 40)
plt.hlines(y=0, xmin=0, xmax=100)
plt.title('Residual plot')
plt.ylabel('Residual')
# Out:
# Text(0, 0.5, 'Residual')
